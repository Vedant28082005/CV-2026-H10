# %% [markdown]
# <a href="https://colab.research.google.com/github/Vedant28082005/CV-2026-H10/blob/main/LAB1/CV_Lab_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2

# %%
img = cv2.imread('/content/rename.png')

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=250x257>

# %%
img.shape
# Out:
# (257, 250, 3)

# %%
resize = np.resize(img,(256,256,3))

# %%
resize.shape
# Out:
# (256, 256, 3)

# %%
cv2_imshow(resize)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
img.dtype
# Out:
# dtype('uint8')

# %%
crop = img[30:227 , 50:200]

# %%
#cvt is remaining

rgb = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
cv2_imshow(rgb)
# Out:
# <PIL.Image.Image image mode=RGB size=250x257>

# %%
crop[30,50] = [0,0,0]

# %%
cv2_imshow(crop)
# Out:
# <PIL.Image.Image image mode=RGB size=150x197>

# %%
#grayscaling_remaining to implement

gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=250x257>

# %%
img = cv2.imread('/content/rename.png')

# %%
"""red = img[:,:,2]
green = img[:,:,1]
blue = img[:,:,0]"""

r, g, b = np.dsplit(img, 3)

# %%
cv2_imshow(r)
cv2_imshow(g)
cv2_imshow(b)
# Out:
# <PIL.Image.Image image mode=RGB size=250x257>
# <PIL.Image.Image image mode=RGB size=250x257>
# <PIL.Image.Image image mode=RGB size=250x257>
